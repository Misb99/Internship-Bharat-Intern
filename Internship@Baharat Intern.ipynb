# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
data=pd.read_csv("TSLA.csv")
data.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-10-10  223.929993  226.990005  218.360001  222.960007  222.960007
# 1  2022-10-11  220.949997  225.750000  215.000000  216.500000  216.500000
# 2  2022-10-12  215.330002  219.300003  211.509995  217.240005  217.240005
# 3  2022-10-13  208.300003  222.990005  206.220001  221.720001  221.720001
# 4  2022-10-14  224.009995  226.259995  204.160004  204.990005  204.990005
# 5  2022-10-17  210.039993  221.860001  209.449997  219.350006  219.350006
# 6  2022-10-18  229.500000  229.820007  217.250000  220.190002  220.190002
# 7  2022-10-19  219.800003  222.929993  217.779999  222.039993  222.039993
# 8  2022-10-20  208.279999  215.550003  202.000000  207.279999  207.279999
# 9  2022-10-21  206.419998  214.660004  203.800003  214.440002  214.440002
#
#       Volume
# 0   67925000
# 1   77013200
# 2   66860700
# 3   91483000
# 4   94124500
# 5   79428800
# 6   75891900
# 7   66571500
# 8  117798100
# 9   75713800

# %%
data.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 246  2023-10-03  248.610001  250.020004  244.449997  246.529999  246.529999
# 247  2023-10-04  248.139999  261.859985  247.600006  261.160004  261.160004
# 248  2023-10-05  260.000000  263.600006  256.250000  260.049988  260.049988
# 249  2023-10-06  253.979996  261.649994  250.649994  260.529999  260.529999
# 250  2023-10-09  255.309998  261.359985  252.050003  259.670013  259.670013
#
#         Volume
# 246  101985300
# 247  129721600
# 248  119159200
# 249  117947000
# 250  101156100

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
data.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   205.693347  210.264661  201.031235  205.859362  205.859362
# std     44.124405   44.516468   43.814266   44.236692   44.236692
# min    103.000000  111.750000  101.809998  108.099998  108.099998
# 25%    176.635002  182.419998  172.504998  178.474998  178.474998
# 50%    198.539993  203.000000  192.889999  197.580002  197.580002
# 75%    245.235001  251.450005  242.014999  246.455002  246.455002
# max    296.040009  299.290009  289.519989  293.339996  293.339996
#
#              Volume
# count  2.510000e+02
# mean   1.338845e+08
# std    4.177558e+07
# min    5.067270e+07
# 25%    1.037006e+08
# 50%    1.270627e+08
# 75%    1.605998e+08
# max    3.065906e+08

# %%
data.nunique()
# Out:
# Date         251
# Open         249
# High         246
# Low          248
# Close        248
# Adj Close    248
# Volume       251
# dtype: int64

# %%
data.shape
# Out:
# (251, 7)

# %%
data.isnull()
# Out:
#       Date   Open   High    Low  Close  Adj Close  Volume
# 0    False  False  False  False  False      False   False
# 1    False  False  False  False  False      False   False
# 2    False  False  False  False  False      False   False
# 3    False  False  False  False  False      False   False
# 4    False  False  False  False  False      False   False
# ..     ...    ...    ...    ...    ...        ...     ...
# 246  False  False  False  False  False      False   False
# 247  False  False  False  False  False      False   False
# 248  False  False  False  False  False      False   False
# 249  False  False  False  False  False      False   False
# 250  False  False  False  False  False      False   False
#
# [251 rows x 7 columns]

# %%
fig,axes=plt.subplots(nrows=3,ncols=2,figsize=(20,20))
data.plot(x='Date',y='Open',ax=axes[0,0])
data.plot(x='Date',y='High',ax=axes[0,1])
data.plot(x='Date',y='Low',ax=axes[1,0])
data.plot(x='Date',y='Close',ax=axes[1,1])
data.plot(x='Date',y='Adj Close',ax=axes[2,0])
data.plot(x='Date',y='Volume',ax=axes[2,1])
# Out:
# <Axes: xlabel='Date'>

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data.boxplot(figsize=(10,5))
# Out:
# <Axes: >

# %%
data.select_dtypes(include='float')
# Out:
#            Open        High         Low       Close   Adj Close
# 0    223.929993  226.990005  218.360001  222.960007  222.960007
# 1    220.949997  225.750000  215.000000  216.500000  216.500000
# 2    215.330002  219.300003  211.509995  217.240005  217.240005
# 3    208.300003  222.990005  206.220001  221.720001  221.720001
# 4    224.009995  226.259995  204.160004  204.990005  204.990005
# ..          ...         ...         ...         ...         ...
# 246  248.610001  250.020004  244.449997  246.529999  246.529999
# 247  248.139999  261.859985  247.600006  261.160004  261.160004
# 248  260.000000  263.600006  256.250000  260.049988  260.049988
# 249  253.979996  261.649994  250.649994  260.529999  260.529999
# 250  255.309998  261.359985  252.050003  259.670013  259.670013
#
# [251 rows x 5 columns]

# %% [markdown]
# # THANK YOU
# PRESENTED BY MISBAH SAMEEN
